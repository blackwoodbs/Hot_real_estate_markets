# %% [markdown]
# * Who is the stakeholder
#
# * What problem can I solve
#
# * data is from zillow
#
# ### Analyize the data
#
# ### Prepare the data
#
# ### Determine model parameters
#
# ### Evaluate the model
#
# ### Report Findings

# %% [markdown]
# # EDA / Data Prep

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Metro_sales_count_now_uc_sfrcondo_month.csv')
df.head(3)
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
#
#   StateName  2008-02-29  2008-03-31  2008-04-30  2008-05-31  2008-06-30  ...  \
# 0       NaN    185099.0    219079.0    241110.0    259949.0    275074.0  ...
# 1        NY      8096.0      8797.0      9518.0      9797.0     10293.0  ...
# 2        CA      3588.0      4350.0      5163.0      5657.0      5791.0  ...
#
#    2021-04-30  2021-05-31  2021-06-30  2021-07-31  2021-08-31  2021-09-30  \
# 0    463540.0    464142.0    539662.0    498427.0    489178.0    447145.0
# 1     17864.0     17243.0     22149.0     21380.0     21096.0     18527.0
# 2     11212.0     10267.0     11387.0     10453.0      9985.0      9646.0
#
#    2021-10-31  2021-11-30  2021-12-31  2022-01-31
# 0    420659.0    402778.0    407568.0    267873.0
# 1     18693.0     16629.0     18380.0     15923.0
# 2      9367.0      8774.0      8623.0      6332.0
#
# [3 rows x 173 columns]

# %% [markdown]
# ##### Time series manipulation

# %%
droped_cols = ['RegionID', 'SizeRank', 'RegionType', 'StateName']
df.drop(droped_cols, axis=1, inplace=True)
df.set_index('RegionName', inplace=True)
ts = df.T
ts.index = pd.to_datetime(ts.index)
ts
# Out:
# RegionName  United States  New York, NY  Los Angeles-Long Beach-Anaheim, CA  \
# 2008-02-29       185099.0        8096.0                              3588.0
# 2008-03-31       219079.0        8797.0                              4350.0
# 2008-04-30       241110.0        9518.0                              5163.0
# 2008-05-31       259949.0        9797.0                              5657.0
# 2008-06-30       275074.0       10293.0                              5791.0
# ...                   ...           ...                                 ...
# 2021-09-30       447145.0       18527.0                              9646.0
# 2021-10-31       420659.0       18693.0                              9367.0
# 2021-11-30       402778.0       16629.0                              8774.0
# 2021-12-31       407568.0       18380.0                              8623.0
# 2022-01-31       267873.0       15923.0                              6332.0
#
# RegionName  Chicago, IL  Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX  \
# 2008-02-29       4870.0                 5039.0            3754.0       4303.0
# 2008-03-31       5856.0                 6102.0            4608.0       5374.0
# 2008-04-30       6575.0                 6869.0            5512.0       5653.0
# 2008-05-31       6641.0                 7115.0            5418.0       5965.0
# 2008-06-30       7735.0                 7304.0            6059.0       6437.0
# ...                 ...                    ...               ...          ...
# 2021-09-30      16004.0                 9662.0           10352.0       9368.0
# 2021-10-31      13794.0                 9157.0            9447.0       8711.0
# 2021-11-30      11320.0                 8686.0            8997.0       8377.0
# 2021-12-31      10595.0                 8667.0           13251.0       8923.0
# 2022-01-31       7482.0                 7136.0            8788.0       6882.0
#
# RegionName  Washington, DC  Miami-Fort Lauderdale, FL  Atlanta, GA  ...  \
# 2008-02-29          3797.0                     4007.0       5123.0  ...
# 2008-03-31          4571.0                     4412.0       5656.0  ...
# 2008-04-30          4905.0                     4945.0       6182.0  ...
# 2008-05-31          5318.0                     4905.0       5942.0  ...
# 2008-06-30          6372.0                     4860.0       6441.0  ...
# ...                    ...                        ...          ...  ...
# 2021-09-30          9431.0                     9965.0       9946.0  ...
# 2021-10-31          9712.0                     9494.0       9611.0  ...
# 2021-11-30          9957.0                     9713.0       8980.0  ...
# 2021-12-31          9672.0                    11742.0       8593.0  ...
# 2022-01-31          6640.0                     8435.0       6547.0  ...
#
# RegionName  Boise City, ID  Toledo, OH  Madison, WI  Lakeland, FL  Ogden, UT  \
# 2008-02-29           578.0       172.0        310.0         452.0      518.0
# 2008-03-31           691.0       207.0        452.0         576.0      599.0
# 2008-04-30           702.0       232.0        589.0         563.0      655.0
# 2008-05-31           760.0       269.0        718.0         521.0      706.0
# 2008-06-30           797.0       281.0        873.0         578.0      631.0
# ...                    ...         ...          ...           ...        ...
# 2021-09-30          1521.0         NaN        914.0        1400.0        NaN
# 2021-10-31          1466.0         NaN          NaN        1275.0        NaN
# 2021-11-30          1361.0         NaN        767.0           NaN        NaN
# 2021-12-31          1361.0         NaN          NaN        1572.0        NaN
# 2022-01-31          1377.0         NaN        769.0        1473.0      910.0
#
# RegionName  Daytona Beach, FL  Des Moines, IA  Provo, UT  Durham, NC  \
# 2008-02-29              499.0           559.0      293.0       450.0
# 2008-03-31              584.0           612.0      357.0       582.0
# 2008-04-30              608.0           795.0      382.0       609.0
# 2008-05-31              672.0           833.0      409.0       785.0
# 2008-06-30              606.0           948.0      404.0       864.0
# ...                       ...             ...        ...         ...
# 2021-09-30             1703.0          1353.0        NaN       890.0
# 2021-10-31             1671.0          1334.0        NaN       898.0
# 2021-11-30             1623.0          1174.0        NaN       898.0
# 2021-12-31             1907.0          1082.0      794.0       908.0
# 2022-01-31             1668.0          1205.0        NaN       968.0
#
# RegionName  Fort Collins, CO
# 2008-02-29             247.0
# 2008-03-31             361.0
# 2008-04-30             418.0
# 2008-05-31             488.0
# 2008-06-30             529.0
# ...                      ...
# 2021-09-30               NaN
# 2021-10-31               NaN
# 2021-11-30               NaN
# 2021-12-31             666.0
# 2022-01-31             794.0
#
# [168 rows x 95 columns]

# %%
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2008-02-29 to 2022-01-31
# Data columns (total 95 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   United States                       168 non-null    float64
#  1   New York, NY                        160 non-null    float64
#  2   Los Angeles-Long Beach-Anaheim, CA  168 non-null    float64
#  3   Chicago, IL                         167 non-null    float64
#  4   Dallas-Fort Worth, TX               168 non-null    float64
#  5   Philadelphia, PA                    168 non-null    float64
#  6   Houston, TX                         162 non-null    float64
#  7   Washington, DC                      168 non-null    float64
#  8   Miami-Fort Lauderdale, FL           168 non-null    float64
#  9   Atlanta, GA                         168 non-null    float64
#  10  Boston, MA                          168 non-null    float64
#  11  San Francisco, CA                   168 non-null    float64
#  12  Detroit, MI                         168 non-null    float64
#  13  Riverside, CA                       168 non-null    float64
#  14  Phoenix, AZ                         168 non-null    float64
#  15  Seattle, WA                         168 non-null    float64
#  16  Minneapolis-St Paul, MN             168 non-null    float64
#  17  San Diego, CA                       166 non-null    float64
#  18  St. Louis, MO                       168 non-null    float64
#  19  Tampa, FL                           168 non-null    float64
#  20  Baltimore, MD                       168 non-null    float64
#  21  Denver, CO                          168 non-null    float64
#  22  Pittsburgh, PA                      168 non-null    float64
#  23  Portland, OR                        168 non-null    float64
#  24  Charlotte, NC                       168 non-null    float64
#  25  Sacramento, CA                      168 non-null    float64
#  26  San Antonio, TX                     168 non-null    float64
#  27  Orlando, FL                         168 non-null    float64
#  28  Cincinnati, OH                      168 non-null    float64
#  29  Cleveland, OH                       168 non-null    float64
#  30  Kansas City, MO                     168 non-null    float64
#  31  Las Vegas, NV                       160 non-null    float64
#  32  Columbus, OH                        167 non-null    float64
#  33  Indianapolis, IN                    168 non-null    float64
#  34  San Jose, CA                        167 non-null    float64
#  35  Austin, TX                          168 non-null    float64
#  36  Virginia Beach, VA                  168 non-null    float64
#  37  Nashville, TN                       168 non-null    float64
#  38  Providence, RI                      168 non-null    float64
#  39  Milwaukee, WI                       168 non-null    float64
#  40  Jacksonville, FL                    168 non-null    float64
#  41  Memphis, TN                         167 non-null    float64
#  42  Oklahoma City, OK                   168 non-null    float64
#  43  Louisville-Jefferson County, KY     168 non-null    float64
#  44  Hartford, CT                        168 non-null    float64
#  45  Richmond, VA                        168 non-null    float64
#  46  New Orleans, LA                     167 non-null    float64
#  47  Buffalo, NY                         166 non-null    float64
#  48  Raleigh, NC                         166 non-null    float64
#  49  Birmingham, AL                      131 non-null    float64
#  50  Salt Lake City, UT                  168 non-null    float64
#  51  Rochester, NY                       167 non-null    float64
#  52  Grand Rapids, MI                    165 non-null    float64
#  53  Tucson, AZ                          168 non-null    float64
#  54  Urban Honolulu, HI                  155 non-null    float64
#  55  Tulsa, OK                           168 non-null    float64
#  56  Fresno, CA                          162 non-null    float64
#  57  Worcester, MA                       168 non-null    float64
#  58  Stamford, CT                        168 non-null    float64
#  59  Albuquerque, NM                     167 non-null    float64
#  60  Albany, NY                          160 non-null    float64
#  61  Omaha, NE                           142 non-null    float64
#  62  New Haven, CT                       168 non-null    float64
#  63  Bakersfield, CA                     148 non-null    float64
#  64  Knoxville, TN                       167 non-null    float64
#  65  Greenville, SC                      168 non-null    float64
#  66  Ventura, CA                         168 non-null    float64
#  67  Allentown, PA                       167 non-null    float64
#  68  El Paso, TX                         159 non-null    float64
#  69  Baton Rouge, LA                     167 non-null    float64
#  70  Dayton, OH                          168 non-null    float64
#  71  McAllen, TX                         43 non-null     float64
#  72  Columbia, SC                        168 non-null    float64
#  73  Greensboro, NC                      161 non-null    float64
#  74  Akron, OH                           162 non-null    float64
#  75  North Port-Sarasota-Bradenton, FL   168 non-null    float64
#  76  Little Rock, AR                     132 non-null    float64
#  77  Stockton, CA                        167 non-null    float64
#  78  Charleston, SC                      168 non-null    float64
#  79  Syracuse, NY                        163 non-null    float64
#  80  Colorado Springs, CO                168 non-null    float64
#  81  Winston-Salem, NC                   161 non-null    float64
#  82  Wichita, KS                         99 non-null     float64
#  83  Springfield, MA                     167 non-null    float64
#  84  Fort Myers, FL                      168 non-null    float64
#  85  Boise City, ID                      168 non-null    float64
#  86  Toledo, OH                          160 non-null    float64
#  87  Madison, WI                         166 non-null    float64
#  88  Lakeland, FL                        166 non-null    float64
#  89  Ogden, UT                           162 non-null    float64
#  90  Daytona Beach, FL                   168 non-null    float64
#  91  Des Moines, IA                      167 non-null    float64
#  92  Provo, UT                           161 non-null    float64
#  93  Durham, NC                          168 non-null    float64
#  94  Fort Collins, CO                    164 non-null    float64
# dtypes: float64(95)
# memory usage: 126.0 KB

# %%
for x in ts.columns[1:5]:
    ts[x].plot(figsize=(10,6))

# %% [markdown]
# ##### Data preperation - plan
# * Missing Data
#  * Drop cols with significant gaps
#  * Interpolate data with small holes
# * Non Stationary
#  * Slight positive trend
#  * Seasonal trends

# %%
max_missing_values = ts.shape[0] * .1 # 90% threshold for data
max_missing_values
# Out:
# 16.8

# %%
significant_gaps = ts.isna().sum()[ts.isna().sum() > max_missing_values].index
significant_gaps
# Out:
# Index(['Birmingham, AL', 'Omaha, NE', 'Bakersfield, CA', 'McAllen, TX',
#        'Little Rock, AR', 'Wichita, KS'],
#       dtype='object', name='RegionName')

# %% [markdown]
# Viusalization of the incomplete data getting dropped before modeling

# %%
for x in significant_gaps:
    ts[x].plot()

# %%
ts.shape[1]
# Out:
# 95

# %%
ts.drop(significant_gaps, axis=1, inplace=True)
ts.shape[1]
# Out:
# 89

# %% [markdown]
# Visualizing the filling method for missing data that will be including in modeling

# %%
ts['New York, NY'].plot()
# Out:
# <AxesSubplot:>

# %%
ts.interpolate(inplace=True)
ts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 168 entries, 2008-02-29 to 2022-01-31
# Data columns (total 89 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   United States                       168 non-null    float64
#  1   New York, NY                        168 non-null    float64
#  2   Los Angeles-Long Beach-Anaheim, CA  168 non-null    float64
#  3   Chicago, IL                         168 non-null    float64
#  4   Dallas-Fort Worth, TX               168 non-null    float64
#  5   Philadelphia, PA                    168 non-null    float64
#  6   Houston, TX                         168 non-null    float64
#  7   Washington, DC                      168 non-null    float64
#  8   Miami-Fort Lauderdale, FL           168 non-null    float64
#  9   Atlanta, GA                         168 non-null    float64
#  10  Boston, MA                          168 non-null    float64
#  11  San Francisco, CA                   168 non-null    float64
#  12  Detroit, MI                         168 non-null    float64
#  13  Riverside, CA                       168 non-null    float64
#  14  Phoenix, AZ                         168 non-null    float64
#  15  Seattle, WA                         168 non-null    float64
#  16  Minneapolis-St Paul, MN             168 non-null    float64
#  17  San Diego, CA                       168 non-null    float64
#  18  St. Louis, MO                       168 non-null    float64
#  19  Tampa, FL                           168 non-null    float64
#  20  Baltimore, MD                       168 non-null    float64
#  21  Denver, CO                          168 non-null    float64
#  22  Pittsburgh, PA                      168 non-null    float64
#  23  Portland, OR                        168 non-null    float64
#  24  Charlotte, NC                       168 non-null    float64
#  25  Sacramento, CA                      168 non-null    float64
#  26  San Antonio, TX                     168 non-null    float64
#  27  Orlando, FL                         168 non-null    float64
#  28  Cincinnati, OH                      168 non-null    float64
#  29  Cleveland, OH                       168 non-null    float64
#  30  Kansas City, MO                     168 non-null    float64
#  31  Las Vegas, NV                       168 non-null    float64
#  32  Columbus, OH                        168 non-null    float64
#  33  Indianapolis, IN                    168 non-null    float64
#  34  San Jose, CA                        168 non-null    float64
#  35  Austin, TX                          168 non-null    float64
#  36  Virginia Beach, VA                  168 non-null    float64
#  37  Nashville, TN                       168 non-null    float64
#  38  Providence, RI                      168 non-null    float64
#  39  Milwaukee, WI                       168 non-null    float64
#  40  Jacksonville, FL                    168 non-null    float64
#  41  Memphis, TN                         168 non-null    float64
#  42  Oklahoma City, OK                   168 non-null    float64
#  43  Louisville-Jefferson County, KY     168 non-null    float64
#  44  Hartford, CT                        168 non-null    float64
#  45  Richmond, VA                        168 non-null    float64
#  46  New Orleans, LA                     168 non-null    float64
#  47  Buffalo, NY                         168 non-null    float64
#  48  Raleigh, NC                         168 non-null    float64
#  49  Salt Lake City, UT                  168 non-null    float64
#  50  Rochester, NY                       168 non-null    float64
#  51  Grand Rapids, MI                    168 non-null    float64
#  52  Tucson, AZ                          168 non-null    float64
#  53  Urban Honolulu, HI                  168 non-null    float64
#  54  Tulsa, OK                           168 non-null    float64
#  55  Fresno, CA                          168 non-null    float64
#  56  Worcester, MA                       168 non-null    float64
#  57  Stamford, CT                        168 non-null    float64
#  58  Albuquerque, NM                     168 non-null    float64
#  59  Albany, NY                          168 non-null    float64
#  60  New Haven, CT                       168 non-null    float64
#  61  Knoxville, TN                       168 non-null    float64
#  62  Greenville, SC                      168 non-null    float64
#  63  Ventura, CA                         168 non-null    float64
#  64  Allentown, PA                       168 non-null    float64
#  65  El Paso, TX                         168 non-null    float64
#  66  Baton Rouge, LA                     168 non-null    float64
#  67  Dayton, OH                          168 non-null    float64
#  68  Columbia, SC                        168 non-null    float64
#  69  Greensboro, NC                      168 non-null    float64
#  70  Akron, OH                           168 non-null    float64
#  71  North Port-Sarasota-Bradenton, FL   168 non-null    float64
#  72  Stockton, CA                        168 non-null    float64
#  73  Charleston, SC                      168 non-null    float64
#  74  Syracuse, NY                        168 non-null    float64
#  75  Colorado Springs, CO                168 non-null    float64
#  76  Winston-Salem, NC                   168 non-null    float64
#  77  Springfield, MA                     168 non-null    float64
#  78  Fort Myers, FL                      168 non-null    float64
#  79  Boise City, ID                      168 non-null    float64
#  80  Toledo, OH                          168 non-null    float64
#  81  Madison, WI                         168 non-null    float64
#  82  Lakeland, FL                        168 non-null    float64
#  83  Ogden, UT                           168 non-null    float64
#  84  Daytona Beach, FL                   168 non-null    float64
#  85  Des Moines, IA                      168 non-null    float64
#  86  Provo, UT                           168 non-null    float64
#  87  Durham, NC                          168 non-null    float64
#  88  Fort Collins, CO                    168 non-null    float64
# dtypes: float64(89)
# memory usage: 118.1 KB

# %%
ts['New York, NY'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modeling

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.api import SARIMAX
import statsmodels.api as sm

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

from statsmodels.tsa.stattools import adfuller

import warnings
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
                        FutureWarning)
warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
                        FutureWarning)

# %%
def ts_comp(timeseries):
    no_null_ts = timeseries.dropna()
    
    fig, ax = plt.subplots(figsize=(16,3))
    plot_acf(no_null_ts, ax=ax);

    fig, ax = plt.subplots(figsize=(16,3))
    plot_pacf(no_null_ts, ax=ax);
    
    if adfuller(no_null_ts)[1] > 0.05:
        print('not stationary')
    else:
        print('stationary')
    
def print_arima_summary(timeseries, order=(1,1,1)):
    arima_model = ARIMA(timeseries, order=order)
    res_arima = arima_model.fit()
    print(res_arima.summary())
    return res_arima

# %%
ts['United States'].plot()
ts_comp(ts['United States'])
# Out:
# not stationary

# %% [markdown]
# * Differencing made the data stationary per the adfuller test but significant correlation can be observed at 12 periods (1 year).

# %%
one_lag_diff_us = ts['United States'].diff()
one_lag_diff_us.plot()
ts_comp(one_lag_diff_us)
# Out:
# stationary

# %%
model_1 = print_arima_summary(one_lag_diff_us, (1,0,1))
model_1
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:          United States   No. Observations:                  168
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2031.182
# Date:                Wed, 16 Feb 2022   AIC                           4070.364
# Time:                        10:44:37   BIC                           4082.860
# Sample:                    02-29-2008   HQIC                          4075.435
#                          - 01-31-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        495.6577   1560.705      0.318      0.751   -2563.268    3554.584
# ar.L1          0.7324      0.098      7.458      0.000       0.540       0.925
# ma.L1         -0.9555      0.071    -13.481      0.000      -1.094      -0.817
# sigma2       2.37e+09      0.000   5.76e+12      0.000    2.37e+09    2.37e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.48   Jarque-Bera (JB):                 3.11
# Prob(Q):                              0.49   Prob(JB):                         0.21
# Heteroskedasticity (H):               2.90   Skew:                            -0.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.53e+28. Standard errors may be unstable.
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'

# %%
sarimax_test = SARIMAX(ts['United States'][:'2019'], order=(0,1,0), seasonal_order=(1,0,1,12)).fit()
sarimax_test.summary()

ts['United States']['2015':].plot()
sarimax_test.predict(start="2020", end="2022").plot()

print(sarimax_test.aic)
# Out:
# 3331.6700913935933
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'

# %%
sarimax_err = pd.concat([ts['United States']['2020'], sarimax_test.predict(start="2020", end="2021")], axis=1)
sarimax_err['error'] = (sarimax_err['United States'] - sarimax_err['predicted_mean'])**2
rmse = sarimax_err['error'].mean()**0.5
rmse
# Out:
# 67988.14832048773

# %%
# two_lag_diff_us = one_lag_diff_us.diff()
# two_lag_diff_us.plot()
# ts_comp(two_lag_diff_us)

# %%
# model_2 = print_arima_summary(two_lag_diff_us, (3,0,2))
# model_2

# %%
# two_lag_diff_us_once = ts['United States'].diff(2)
# two_lag_diff_us_once.plot()
# ts_comp(two_lag_diff_us_once)

# %%
# model_3 = print_arima_summary(two_lag_diff_us_once, (2,0,2))
# model_3

# %%
# four_lag_diff_us_once = ts['United States'].diff(4)
# four_lag_diff_us_once.plot()
# ts_comp(four_lag_diff_us_once)

# %%
# model_4 = print_arima_summary(four_lag_diff_us_once, (2,0,3))
# model_4

# %%
# twelve_lag_diff_us_once = ts['United States'].diff(12)
# twelve_lag_diff_us_once.plot()
# ts_comp(twelve_lag_diff_us_once)

# %%
# six_lag_diff_us_once = ts['United States'].diff(6)
# six_lag_diff_us_once.plot()
# ts_comp(six_lag_diff_us_once)

# %%
# for x in [model_1, model_2, model_3, model_4]:
#     print(x.aic)

# %%
# for x in [model_1, model_2, model_3, model_4]:
#     print(x.bic)

# %%
# model_4.forecast(6)

# %%
results = 1000000

for x in range(5):
    for y in range(1,2):
        for z in range(5):
            sample = SARIMAX(ts['United States'][:'2019'], order=(0,1,0), seasonal_order=(x,y,z,12)).fit()
#             sample.summary()
            aic = sample.aic
            
            temp_df = None
            temp_df = pd.concat([ts['United States']['2020':'2021'], sample.predict(start="2020", end="2022")], axis=1)
            temp_df['error'] = (temp_df['United States'] - temp_df['predicted_mean'])**2
            rmse = temp_df['error'].mean()**0.5
#             print(x, y, z, rmse)
            if aic < results:
                results = aic
                print(aic, x, y, z, rmse)
                plt.figure()
                ts['United States']['2015':].plot()
                ax = sample.predict(start="2020", end="2023").plot()
                ax.set_title(f'order = ({x}, {y}, {z}, 12)');
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# 3020.4850567824406 0 1 0 67878.50595273146
# 3008.9852330872027 0 1 2 55770.452738953005
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1008: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# 3001.6185679129503 0 1 3 59636.15442472415
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1008: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# 3001.156987049006 1 1 4 55832.33677761753
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# 2991.3108579775762 2 1 2 58409.383163480066
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1008: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# 2987.271628212231 2 1 3 64870.25322157368
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# 2984.5032040386877 3 1 2 65478.06331139837
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:1008: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:996: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
seasonal_ord = (1,1,4,12)

# %%
for x in ts.columns[:10]:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()
    
    temp_df = None
    temp_df = pd.concat([ts[x]['2020':'2021'], optimized_sm.predict(start="2020", end="2022")], axis=1)
    temp_df['error'] = (temp_df[x] - temp_df['predicted_mean'])**2
    rmse = temp_df['error'].mean()**0.5
            
    plt.figure()
    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2022").plot()
    ax.set_title(f'{x}: rmse = {str(round(rmse, 2))}');
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# optimized_sm = SARIMAX(ts['United States'][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

# ts['United States']['2015':].plot()
# ax = optimized_sm.predict(start="2020", end="2023").plot()
# ax.set_title('United States');

# %%
# for x in ts.columns[2:3]:
#     optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

#     ts[x]['2015':].plot()
#     ax = optimized_sm.predict(start="2020", end="2023").plot()
#     ax.set_title(x);

# %%
# for x in ts.columns[5:6]:
#     optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

#     ts[x]['2015':].plot()
#     ax = optimized_sm.predict(start="2020", end="2023").plot()
#     ax.set_title(x);

# %%
# for x in ts.columns[16:17]:
#     optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

#     ts[x]['2015':].plot()
#     ax = optimized_sm.predict(start="2020", end="2023").plot()
#     ax.set_title(x);

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
ss = StandardScaler()
scaled_ts = ss.fit_transform(ts[:-1])
scaled_df = pd.DataFrame(scaled_ts)
scaled_df.set_index(ts[:-1].index, inplace=True)
scaled_df.columns = ts.columns
scaled_df

mm = MinMaxScaler()
mm_ts = mm.fit_transform(ts[:-1])
mm_df = pd.DataFrame(mm_ts)
mm_df.set_index(ts[:-1].index, inplace=True)
mm_df.columns = ts.columns
mm_df

# %%
optimized_sm = SARIMAX(scaled_df['United States'][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

scaled_df['United States'].plot()
ax = optimized_sm.predict(start="2020", end="2023").plot()
ax.set_title('United States');

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### This cell takes a long time to run

# %%
arr = []
for x in scaled_df.columns:
    sarimax_test = SARIMAX(scaled_df[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()
    
    lr = LinearRegression()
    z = pd.DataFrame(sarimax_test.predict(start='2020', end='2021'))
    y = z.index
    lr.fit(z.values, y)
    arr.append((x, lr.coef_[0]))
    
    
slope_test_df = pd.DataFrame(arr)
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# ...
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
slope_test_df.sort_values(1).head(25)
# Out:
#                                     0             1
# 78                     Fort Myers, FL -3.686216e+15
# 52                         Tucson, AZ -4.383076e+14
# 71  North Port-Sarasota-Bradenton, FL -2.586283e+14
# 66                    Baton Rouge, LA -2.500386e+14
# 81                        Madison, WI -1.722692e+14
# 54                          Tulsa, OK -5.532851e+13
# 34                       San Jose, CA  1.829861e+14
# 35                         Austin, TX  3.040601e+14
# 14                        Phoenix, AZ  3.144003e+14
# 49                 Salt Lake City, UT  4.597291e+14
# 83                          Ogden, UT  5.974394e+14
# 46                    New Orleans, LA  8.273361e+14
# 17                      San Diego, CA  1.041635e+15
# 42                  Oklahoma City, OK  1.089928e+15
# 79                     Boise City, ID  1.154190e+15
# 86                          Provo, UT  1.173925e+15
# 63                        Ventura, CA  1.221730e+15
# 36                 Virginia Beach, VA  1.279548e+15
# 26                    San Antonio, TX  1.340765e+15
# 62                     Greenville, SC  1.378361e+15
# 39                      Milwaukee, WI  1.461377e+15
# 31                      Las Vegas, NV  1.473896e+15
# 58                    Albuquerque, NM  1.508593e+15
# 30                    Kansas City, MO  1.549940e+15
# 11                  San Francisco, CA  1.603273e+15

# %%
for x in ['Fort Myers, FL']:
    optimized_sm = SARIMAX(ts[x]['2015':'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for x in ['Tucson, AZ']:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for x in ['North Port-Sarasota-Bradenton, FL']:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for x in ['Baltimore, MD']:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for x in ['Urban Honolulu, HI']:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
for x in ['New York, NY']:
    optimized_sm = SARIMAX(ts[x][:'2019'], order=(0,1,0), seasonal_order=seasonal_ord).fit()

    ts[x]['2015':].plot()
    ax = optimized_sm.predict(start="2020", end="2023").plot()
    ax.set_title(x);
# Out:
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency M will be used.
#   warnings.warn('No frequency information was'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:865: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /Users/blackwoodbs/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
lr = LinearRegression()
x = pd.DataFrame(sarimax_test.predict(start='2020', end='2021'))
y = x.index
lr.fit(x.values, y)
lr.coef_
# Out:
# array([1.09181497e+16])

# %% [markdown]
# # Todos
#
# * Compare Model performance (RMSE) between scaled and unscaled data
# * Find different metrics for ranking regions (to compare against lr.coef)
# * Cut out/clean up unnessasary code
# * Add MD
# * Start on slide deck
# * Forcast validated model
# * Compare against non ts modeled simple linear regression/moving average prediction or something

# %%
ts_y = ts.asfreq('Y')
ts_y
# Out:
# RegionName  United States  New York, NY  Los Angeles-Long Beach-Anaheim, CA  \
# 2008-12-31       179523.0        8367.0                              4807.0
# 2009-12-31       234099.0       11184.0                              7780.0
# 2010-12-31       200344.0        7801.0                              6962.0
# 2011-12-31       218821.0        8209.0                              6952.0
# 2012-12-31       258684.0        9353.0                              9145.0
# 2013-12-31       285170.0       11933.0                              8500.0
# 2014-12-31       316058.0       12498.0                              8536.0
# 2015-12-31       349979.0       13557.0                              9583.0
# 2016-12-31       377260.0       15986.0                              9495.0
# 2017-12-31       375722.0       15671.0                              9140.0
# 2018-12-31       345980.0       15006.0                              7269.0
# 2019-12-31       390054.0       16056.0                              8803.0
# 2020-12-31       481411.0       22416.0                             10449.0
# 2021-12-31       407568.0       18380.0                              8623.0
#
# RegionName  Chicago, IL  Dallas-Fort Worth, TX  Philadelphia, PA  Houston, TX  \
# 2008-12-31       4264.0                 4740.0            4384.0       4482.0
# 2009-12-31       6234.0                 5363.0            6000.0       4938.0
# 2010-12-31       4445.0                 4610.0            3969.0       3604.0
# 2011-12-31       5443.0                 5038.0            4020.0       4326.0
# 2012-12-31       5977.0                 5867.0            4588.0       4629.0
# 2013-12-31       7823.0                 6508.0            5248.0       5573.0
# 2014-12-31       8797.0                 7154.0            5766.0       6754.0
# 2015-12-31       9382.0                 8334.0            6382.0       6739.0
# 2016-12-31       9461.0                 8414.0            6564.0       6979.0
# 2017-12-31       8893.0                 8554.0            6830.0       7183.0
# 2018-12-31       9134.0                 7482.0            6604.0       6649.0
# 2019-12-31       9294.0                 8705.0            7409.0       7794.0
# 2020-12-31      14233.0                10097.0            9399.0       9880.0
# 2021-12-31      10595.0                 8667.0           13251.0       8923.0
#
# RegionName  Washington, DC  Miami-Fort Lauderdale, FL  Atlanta, GA  ...  \
# 2008-12-31          4773.0                     3853.0       4214.0  ...
# 2009-12-31          5952.0                     6024.0       5267.0  ...
# 2010-12-31          5244.0                     5844.0       3878.0  ...
# 2011-12-31          5032.0                     6491.0       3897.0  ...
# 2012-12-31          5616.0                     7164.0       4577.0  ...
# 2013-12-31          6584.0                     7628.0       5629.0  ...
# 2014-12-31          6992.0                     8269.0       6967.0  ...
# 2015-12-31          8107.0                     8809.0       8204.0  ...
# 2016-12-31          7963.0                     9088.0      10838.0  ...
# 2017-12-31          7681.0                     8701.0      10521.0  ...
# 2018-12-31          7543.0                     8030.0       9580.0  ...
# 2019-12-31          8336.0                     8988.0      10668.0  ...
# 2020-12-31          9910.0                    11682.0      11692.0  ...
# 2021-12-31          9672.0                    11742.0       8593.0  ...
#
# RegionName  Boise City, ID  Toledo, OH  Madison, WI  Lakeland, FL   Ogden, UT  \
# 2008-12-31           472.0       169.0        319.0         446.0  455.000000
# 2009-12-31           592.0       233.0        399.0         503.0  455.000000
# 2010-12-31           778.0       198.0        340.0         401.0  411.000000
# 2011-12-31           765.0       234.0        344.0         538.0  487.000000
# 2012-12-31           798.0       285.0        467.0         561.0  605.000000
# 2013-12-31           924.0       341.0        544.0         747.0  598.000000
# 2014-12-31           955.0       353.0        641.0         755.0  687.000000
# 2015-12-31          1228.0       472.0        597.0         944.0  809.000000
# 2016-12-31          1310.0       514.0        739.0        1111.0  913.000000
# 2017-12-31          1340.0       442.0        670.0        1183.0  814.000000
# 2018-12-31          1066.0       402.0        630.0        1195.0  673.000000
# 2019-12-31          1214.0       451.0        646.0        1508.0  803.000000
# 2020-12-31          1215.0       534.0        817.0        1602.0  820.000000
# 2021-12-31          1361.0       555.0        768.0        1572.0  909.142857
#
# RegionName  Daytona Beach, FL  Des Moines, IA  Provo, UT  Durham, NC  \
# 2008-12-31              489.0           512.0      317.0       395.0
# 2009-12-31              767.0           544.0      423.0       445.0
# 2010-12-31              707.0           544.0      364.0       403.0
# 2011-12-31              832.0           686.0      483.0       386.0
# 2012-12-31              928.0           809.0      476.0       465.0
# 2013-12-31             1039.0           857.0      500.0       625.0
# 2014-12-31             1217.0           974.0      560.0       609.0
# 2015-12-31             1417.0          1045.0      644.0       752.0
# 2016-12-31             1361.0          1129.0      710.0       901.0
# 2017-12-31             1521.0          1145.0      670.0       892.0
# 2018-12-31             1472.0          1048.0      568.0       892.0
# 2019-12-31             1697.0          1123.0      661.0      1055.0
# 2020-12-31             1957.0          1393.0      717.0       876.0
# 2021-12-31             1907.0          1082.0      794.0       908.0
#
# RegionName  Fort Collins, CO
# 2008-12-31             248.0
# 2009-12-31             340.0
# 2010-12-31             306.0
# 2011-12-31             325.0
# 2012-12-31             456.0
# 2013-12-31             532.0
# 2014-12-31             609.0
# 2015-12-31             684.0
# 2016-12-31             652.0
# 2017-12-31             600.0
# 2018-12-31             558.0
# 2019-12-31             679.0
# 2020-12-31             723.0
# 2021-12-31             666.0
#
# [14 rows x 89 columns]

# %%
temp['Fort Myers, FL'].plot()
# Out:
# <AxesSubplot:>
